# %% [markdown]
# <a href="https://colab.research.google.com/github/suryoadig12/PACMANN_SKILL100/blob/main/Basic%20Python%20Programming/3.2%20Primitive%20Data%20Structure%3A%20String.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pertemuan 2-3 - String**

# %% [markdown]
# **3. String**

# %% [markdown]
# String adalah **kumpulan huruf, kata atau karakter yang lain**. Di Python String bisa dibuat dengan tanda kutip tunggal `('...')` atau ganda `("...")`.
#
# Di dunia nyata string bisa digunakan untuk cek plagiasi, deteksi spam pada email, bahkan untuk search engine.
#
# Gambar di bawah ini adalah proses saat training data pada machine learning. Dengan string kita bisa memantau proses training data untuk mengetahui model yang kita bangun bagus apa tidak secara langsung.

# %% [markdown]
# ![sadfds.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# Contoh sebuah string: `"google"`, `'python'`, `'data_'` `'@'` dsb.

# %%
# Coba jalankan kode di bawah ini

print('pintu')
# Out:
# pintu

# %%
# Isi titik-titik dibawah dengan kata "sate meranggi"

print("sate maranggi")
# Out:
# sate maranggi

# %%
# Coba print kota tempat tinggal sekarang dengan petik ganda

print("Madiun")
# Out:
# Madiun

# %% [markdown]
# Bagaimana jika kita ingin **menggunakan tanda kutip di dalam string**?
#
# Jika menggunakan **kutip ganda** `("...")` untuk definisi string, maka bisa digunakan **kutip tunggal** `('...')` di dalam teks.

# %%
# Coba lengkapi kode dibawah sehingga bisa di print

print("hello, it's me")
# Out:
# hello, it's me

# %% [markdown]
# Jika menggunakan **kutip tunggal** `('...')` untuk definisi string, maka bisa menggunakan **kutip ganda** `("...")` di dalam teks.

# %%
# coba lengkapi kode di bawah ini sehingga bisa di print

print('"Terbentur, terbentur, terbentuk" kata Tan Malaka.')
# Out:
# "Terbentur, terbentur, terbentuk" kata Tan Malaka.

# %% [markdown]
# Apakah bisa menggunakan kutip tunggal dan ganda secara bersamaan? Untuk itu Python memungkinkan kita untuk menggunakan **tanda kutip tiga** `('''...''')`.
#
# Untuk membuatnya kita bisa menggunakan **kutip tunggal** ('') sebanyak tiga kali.

# %%
# Coba jalankan kode di bawah ini

print('''"That's great", she said.''')
# Out:
# "That's great", she said.

# %%
# Lengkapi titik titik dengan tanda kutip tiga

print('''He said, "What's there?"''')
# Out:
# He said, "What's there?"

# %% [markdown]
# Untuk menyimpan string di dalam variabel caranya sama dengan menyimpan integer atau float, namun untuk definisi string tetap harus menggunakan tanda kutip.

# %%
# Coba lengkapi titik-titik dibawah sehingga bisa di print
string_1 = "ayah membeli kuda baru"
print(string_1)
# Out:
# ayah membeli kuda baru

# %%
# Coba print variabel di bawah ini

string_2 = 'kuda itu aku beri nama jambul'
print(string_2)
# Out:
# kuda itu aku beri nama jambul

# %% [markdown]
# Untuk memeriksa bahwa tipe data yang kita tulis adalah string bisa dengan cara `type(VALUE)`.

# %%
# Coba isi titik-titik dibawah dengan type

mobil = 'porsche'
print(type(mobil))
# Out:
# <class 'str'>

# %%
# Coba buat sebuah variabel bernama hewan
# Kemudian isi variabel tersebut dengan string kelinci
# Selanjutnya cek tipe data variabel tersebut

animal = "Kelinci"
print(type(animal))
# Out:
# <class 'str'>

# %% [markdown]
# Angka yang didefinisikan dengan tanda kutip juga merupakan string.

# %%
# Coba lengkapi code dibawah
angka = '17'
print(type(angka))
# Out:
# <class 'str'>

# %% [markdown]
# **String Operator**

# %% [markdown]
# Di Python, string operator mewakili berbagai jenis operasi yang dapat digunakan pada tipe data string. Berikut ini adalah beberapa string operator yang sering digunakan.

# %% [markdown]
# Misalkan:
#
#       STR_1 = 'data'
#       STR_2 = 'science'

# %% [markdown]
# ![asldjflas.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# **Concatenation**

# %% [markdown]
# Concatenation `(STR_VALUE1 + STR_VALUE2)` berfungsi untuk **menggabungkan** dua string atau lebih.

# %%
# Jalankan kode dibawah

print('pergi'+'jauh')
# Out:
# pergijauh

# %% [markdown]
# Atau bisa juga dengan menggunakan variabel.

# %%
# Coba isi code dibawah dengan operasi concatenation

string_1 = 'pergi'
string_2 = 'jauh'
print(string_1+string_2)
# Out:
# pergijauh

# %% [markdown]
# **Repetition**

# %% [markdown]
# Operator repetition `(STR_VALUE*n)` berfungsi untuk **mengulang string** sebanyak n kali sesuai yang kita inginkan.

# %%
# Coba jalankan kode dibawah ini

print("ayam"*3)
# Out:
# ayamayamayam

# %% [markdown]
# Cara ini bisa juga dilakukan dengan menggunakan variabel.

# %%
# Coba isi variabel hewan dengan string "ayam"
# Ulangi variabel hewan saat di print sebanyak 5 kali

hewan = "ayam"
print(hewan*5)
# Out:
# ayamayamayamayamayam

# %%
# Coba buatlah variabel tanaman dan isilah variabel dengan string "bunga"
# Ulangi variabel tanaman saat di print sebanyak 4 kali

tanaman = "bunga"
print(tanaman*4)
# Out:
# bungabungabungabunga

# %% [markdown]
# **Slicing**

# %% [markdown]
# Pada string kita bisa mengambil karakter yang kita inginkan dengan cara mengakses indeks dari string tersebut. Perlu di ingat indeks pada Python dimulai dengan 0.

# %% [markdown]
# ![asldjfewor.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# Cara untuk melakukan slicing bisa menggunakan **kurung siku** `[]`.
#
# Contohnya jika kita ingin mengambil karakter ke-4 pada sebuah string maka caranya `NAMA_VAR[4]`.

# %%
# Coba kita jalankan code dibawah ini

jam = 'jam tangan'
print(jam[4])
# Out:
# t

# %%
# Lengkapi titik-titik dibawah dengan kata jam

jam = 'jam tangan'
print(jam[1])
# Out:
# a

# %%
# Coba ambillah karakter n pada string jam

jam = 'jam tangan'
print(jam[9])
# Out:
# n

# %% [markdown]
# Bagaimana jika ingin **mendapatkan beberapa karakter** secara langsung? Bisa menggunakan `NAMA_VAR[start:stop-1]`. Operator ini akan mengambil karakter dari indeks `start` sampai ke indeks `stop-1` dari string. Untuk mengambil seluruh nilai pada string menggunakan notasi `[:]`.

# %%
# Coba jalankan kode di bawah ini

jam = 'jam tangan'
print(jam[:])
# Out:
# jam tangan

# %% [markdown]
# Kita akan coba mengambil indeks ke 1 - 5 pada kata `'jam tangan'` berarti notasinya `[1:6]`.

# %% [markdown]
# ![lsdfjlasd.JPG](data:image/jpeg;base64,...)

# %%
# Coba lengkapi titik-titik dibawah ini dengan variabel jam

jam = 'jam tangan'
print(jam[1:6])
# Out:
# am ta

# %%
# Coba ambilah kata jam dengan slicing

jam = 'jam tangan'
print(jam[0:3])
# Out:
# jam

# %% [markdown]
# Jika kita ingin mengambil karakter yang diawali indeks ke `n` sampai akhir string, bisa menggunakan `[n:]`.

# %%
# Coba jalankan code dibawah ini

jam = 'jam tangan'
print(jam[1:])
# Out:
# am tangan

# %%
# Coba isi titik-titik dibawah dari index ke 2

jam = 'jam tangan'
print(jam[2:])
# Out:
# m tangan

# %%
# Coba ambil kata tangan pada pada variabel jam

jam = 'jam tangan'
print(jam[4:])
# Out:
# tangan

# %% [markdown]
# Jika kita ingin mengambil karakter dari awal string sampai indeks ke `m-1`, bisa menggunakan `[:m]`.

# %%
# Coba jalankan code dibawah ini

jam = 'jam tangan'
print(jam[:6])
# Out:
# jam ta

# %%
# Coba isi titik-titik dibawah dengan index ke 5

jam = 'jam tangan'
print(jam[:5])
# Out:
# jam t

# %%
# Coba ambil kata jam pada pada nilai string jam

jam = 'jam tangan'
print(jam[:3])
# Out:
# jam

# %% [markdown]
# Apakah bisa menggunakan **angka negatif** dalam string slicing? Bisa.

# %% [markdown]
# ![sdlafjlsd.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# Menggunakan angka negatif sebagai indeks dalam Python akan mengembalikan elemen ke-n dari **sisi kanan** (berlawanan dengan sisi kiri yang biasa).
#
# Kelebihan menggunakan metode ini yaitu, daripada kita menghitung indeks dari awal untuk mengambil suatu string yang berada di akhir kalimat atau kata, kita bisa langsung mengakses indeksnya menggunakan slicing negatif.

# %%
# Coba jalankan code dibawah

jam = 'jam tangan'
print(jam[-5])
# Out:
# a

# %%
# Ambil nilai indeks negatif satu pada variabel jam

jam = 'jam tangan'
print(jam[-1])
# Out:
# n

# %%
# Dengan slicing, ambil kata jam menggunakan index negatif

jam = 'jam tangan'
print(jam[:-7])
# Out:
# jam

# %% [markdown]
# Kita juga bisa menggunakan **kombinasi indeks negatif dan positif** dalam slicing.

# %%
# Coba jalankan code dibawah

jam = 'jam tangan'
print(jam[-9:5])
# Out:
# am t

# %%
# Dengan kombinasi indeks positif dan negatif, ambil kata 'tanga'

jam = 'jam tangan'
print(jam[4:-1])
# Out:
# tanga

# %% [markdown]
# **Mini Exercise**

# %% [markdown]
# Boss anda menyuruh untuk mengambil data penjualan di bulan tertentu. Bagaimana cara anda untuk mendapatkan hanya bulannya saja di tanggal transaksi tersebut?
#
#       tgl_transaksi_1 = "02-01-2022"
#       tgl_transaksi_2 = "26-05-2022"

# %%
# Transaksi 1
tgl_transaksi_1 = "02-01-2022"
bulan_1 = tgl_transaksi_1[3:5]
print(bulan_1)

# Transaksi 2
tgl_transaksi_2 = "26-05-2022"
bulan_2 = tgl_transaksi_2[3:5]
print(bulan_2)
# Out:
# 01
# 05

# %% [markdown]
# **String Method**

# %% [markdown]
# Ada berbagai macam string methods yang ada di Python. Untuk pertemuan ini, hanya akan dikenalkan beberapa, yaitu sebagai berikut:

# %% [markdown]
# ![dsflasdlf.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# **len()**

# %% [markdown]
# `len()` akan **mengembalikan panjang string** dalam bentuk integer.
#
# Penggunaan: `len(NAMA_VAR)`

# %%
# Jalankan code di bawah

string_1 = 'python programming'
print(len(string_1))
# Out:
# 18

# %%
# Coba cari panjang string kalimat di bawah

lyrics = 'High school in Jakarta, an elaborate saga'
print(len(lyrics))
# Out:
# 41

# %% [markdown]
# **upper()**

# %% [markdown]
# `upper()` akan mengubah semua karakter di dalam string menjadi huruf kapital.
#
# penggunaan: `NAMA_VAR.upper()`

# %%
# Coba jalankan code dibawah ini

pulau = 'Maluku'
print(pulau.upper())
# Out:
# MALUKU

# %%
# Lengkapi kode dibawah ini
# Buat string kota menjadi huruf kapital dengan method upper()

kota = 'surabaya'
print(kota.upper())
# Out:
# SURABAYA

# %% [markdown]
# **lower()**

# %% [markdown]
# `lower()` akan mengubah semua karakter di dalam string menjadi huruf kecil.
#
# penggunaan: `NAMA_VAR.lower()`

# %%
# Coba jalankan code dibawah

alatMusik = 'GITAR'
print(alatMusik.lower())
# Out:
# gitar

# %%
# Coba lengkapi kode dibawah ini
# Jadikan kata di bawah ini menjadi huruf kecil semua menggunakan lower()

bunga = 'anggrek BULAN'
print(bunga.lower())
# Out:
# anggrek bulan

# %% [markdown]
# **count()**

# %% [markdown]
# `count()` akan menghitung karakter di dalam string dan mengembalikannya dalam bentuk integer.
#
# penggunaan: `NAMA_VAR.count('VALUE')`

# %%
# Coba jalankan code dibawah

string_1 = 'python programming'
print(string_1.count('p'))
# Out:
# 2

# %%
# Coba hitung huruf 'o' pada sring_2 menggunakan count()

string_2 = 'jupyter notebook'
print(string_2.count('o'))
# Out:
# 3

# %% [markdown]
# **find()**

# %% [markdown]
# `find()` akan mencari sebuah karakter di dalam string, keluarannya adalah posisi indeks string tersebut.
#
# Jika tidak menemukan maka keluarannya -1
#
# penggunaan: `NAMA_VAR.find('karakter yang dicari')`

# %%
# Coba jalankan code dibawah ini

buah = 'apel'
print(buah.find('e'))
# Out:
# 2

# %%
# Lengkapi kode berikut
# Carilah karakter 'l' ada di indeks ke berapa dengan method find()

buah = 'kelapa'
print(buah.find('l'))
# Out:
# 2

# %% [markdown]
# **replace()**

# %% [markdown]
# `replace()` akan mengganti karakter sesuai dengan apa yang kita inginkan.
#
# penggunaan : `NAMA_VAR.replace('karakter_lama', 'karakter_baru')`

# %%
# Coba jalankan code dibawah

unggas = 'burung bangau'
print(unggas.replace('bangau','elang'))
# Out:
# burung elang

# %%
# Ganti kata pony menjadi jingkrak menggunakan method replace()

hewan = 'kuda pony'
print(hewan.replace("pony", "jingkrak"))
# Out:
# kuda jingkrak

# %%
# Ganti kata Messi menjadi Antony menggunakan method replace()

hewan = 'Messi is the goat'
print(hewan.replace("Messi", "Antony"))
# Out:
# Antony is the goat

# %% [markdown]
# **capitalize()**

# %% [markdown]
# `capitalize()` akan mengubah karakter pertama pada suatu string menjadi huruf kapital.
#
# penggunaan : `NAMA_VAR.capitalize()`

# %%
# Coba jalankan code dibawah

pohon = 'cemara'
print(pohon.capitalize())
# Out:
# Cemara

# %%
# buatlah huruf pertama string dibawah menjadi kapital dengan method capitalize()

word_2 = 'samsul'
print(word_2.capitalize())
# Out:
# Samsul

# %% [markdown]
# **title()**

# %% [markdown]
# `title()` akan mengubah karakter pertama setiap kata pada suatu string menjadi huruf kapital.
#
# penggunaan: `NAMA_VAR.title()`

# %%
# Coba jalankan code dibawah

string_1 = 'antony is the goat'
print(string_1.title())
# Out:
# Antony Is The Goat

# %%
# buatlah huruf pertama pada setiap kata string dibawah menjadi kapital dengan method title()

string_2 = 'business intelligence'
print(string_2.title())
# Out:
# Business Intelligence

# %% [markdown]
# **Mini Exercise**

# %% [markdown]
# Anda diberikan data dari hasil scrapping web. Data tesebut masih 'kotor' dan harus dibersihkan. Salah satu contoh data yang harus dibenarkan disini adalah `"Pyth^*&on Exercis8es"`. Hilangkan karakter yang tidak diperlukan pada string tersebut.
#
# **Hint: menggunakan `.replace()`**

# %%
# Cara 1
string_1 = "Pyth^*&on Exercis8es" # Definisikan dahulu string nya
string_2 = string_1.replace("Pyth^*&on Exercis8es", "Python Exercises") # Ganti langsung seluruh kata pada kalimat tsb menjadi padanan kata yang benar
print(string_2)

# Cara 2
string = "Pyth^*&on Exercis8es" # Definisikan dahulu string nya
string = string.replace("^*&", "") # Replace karakter yang useless pada "Pyth^*&on"
string = string.replace("8", "") # Replace karakter yang useless pada "Exercis8es"
print(string)
# Out:
# Python Exercises
# Python Exercises

# %% [markdown]
# **Exercises**

# %% [markdown]
# Anda memiliki perusahaan percetakan. Pelanggan anda meminta anda untuk mencetak tulisan "HAPPI BIRTHDAY". Namun ternyata di dalam file tulisan yang dikirim, anda menyadari bahwa ada tulisan typo yaitu I di dalam kata HAPPI yang seharusnya huruf Y. Pelanggan meminta anda untuk mengganti dengan yang benar dan mengubah hurufnya menjadi besar di awal kata saja. Coba revisi tulisan HAPPI BIRTHDAY sesuai permintaan pelanggan anda!

# %%
string_1 = "HAPPI BIRTHDAY" # Definisikan string nya terlebih dahulu
string_1 = string_1.replace("HAPPI", "HAPPY") # Ganti kata "HAPPI" menjadi "HAPPY"
string_1 = string_1.title() # Apply method title() agar huruf kapital hanya pada setiap huruf pertama kata saja
print(string_1)
# Out:
# Happy Birthday

# %% [markdown]
# Terdapat kode pos NZ12348, dimana 2 karakter awal adalah kode negara. Coba ambil kode negara dari string tersebut!

# %%
kode_pos = "NZ12348"
kode_negara = kode_pos[0:2]
print(kode_negara)
# Out:
# NZ
