# %% [markdown]
# <a href="https://colab.research.google.com/github/suryoadig12/PACMANN_SKILL100/blob/main/Basic%20Python%20Programming/5.2%20Branching%3A%20Nested%20Branching.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Nested Branching**

# %% [markdown]
# ![sldjfalds.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# *   Nested branching atau **nested-if** adalah suatu kondisi dimana suatu pernyataan bercabang memiliki **pernyataan bercabang didalamnya**.
#
# *   Biasanya digunakan ketika permasalahan semakin kompleks.
#
# *   Namun, hal ini sebenarnya tidak direkomendasikan.
# *   Karena jika nested if sangat panjang, akan mempersulit orang untuk membaca kode.
#
#
# *   Sehingga akan cukup rawan untuk error.

# %% [markdown]
# **Nested Branching**

# %% [markdown]
# Yana saat ini bekerja sebagai sales sebuah brand sepeda motor. Tiap bulan, Yana perlu untuk menjual 10 sepeda motor. Namun, dari kantor dia bisa mendapatkan insentif jika mampu menjual 20 sepeda motor.
#
# Bulan ini, Yana mampu menjual 30 sepeda motor.
#
# Cek status sales Yana apakah sudah memenuhi target atau belum. Dan jika iya, apakah Yana bisa mendapatkan insentif bulan ini.
#
# Maka flowchart atau alur programnya dapat di gambarkan sebagai berikut:

# %% [markdown]
# ![fldsjfalsdf.JPG](data:image/jpeg;base64,...)

# %%
sales_yana = 30
target_penjualan = 10
target_insentif = 20

# Merupakan if <condition> membuat kondisi apakah penjualan Yana lebih besar sama dengan target penjualan
if sales_yana >= target_penjualan:

    # Merupakan nested branching if membuat kondisi apakah penjualan Yana selain mendapatkan target apakah yana mendapatkan insentif
    if sales_yana >= target_insentif:

        # Statement jika bernilai true
        print('Yana memenuhi target dan mendapatkan insentif')

    else:
        # Statement jika bernilai False atau tidak memenuhi pada kondisi sales_yana >= target_insentif
        print('Yana memenuhi target')

else:
    # Statement jika bernilai False atau tidak memenuhi pada kondisi sales_yana >= target_penjualan
    print('Yana belum memenuhi target')
# Out:
# Yana memenuhi target dan mendapatkan insentif

# %% [markdown]
# **Exercise**

# %% [markdown]
# Dokter merawat seorang pasien yang sedang sakit, dokter memiliki beberapa kondisi diagnosa yaitu:
#
#
#
# 1.   Jika pasien flu tanpa gejala sakit tenggorokan bahwa pasien sakit flu biasa.
# 2.   Jika pasien flu ditambah dengan sakit tenggorokan maka pasien sakit radang tenggorokan.
# 3.   Jika pasien flu ditambah sakit tenggorokan ditambah mual maka pasien sakit tonsilitis.
#
# Ternyata terdapat pasien yang mengidap radang tenggorokan. Ubahlah variabel `kondisi_1` dan `kondisi_2` agar mengeluarkan diagnosa "pasien sakit radang tenggorokan".
#
# `Hint: Gunakan Boolean Logic`

# %%
# Tuliskan jawaban anda di bawah ini

kondisi_1 = True
kondisi_2 = False

if kondisi_1 == True :
    if kondisi_2 == True :
        print("pasien sakit tonsilitis")
    else :
        print("pasien sakit radang tenggorokan")
else:
    print("pasien sakit flu biasa")
# Out:
# pasien sakit radang tenggorokan

# %% [markdown]
# Buatlah nested if untuk kondisi berikut jika nilai a kurang dari 10, maka lihat apakah Angka tersebut genap atau ganjil, jika genap maka print "angka genap kecil" jika ganjil "angka ganjil kecil" Selain itu print "angka besar".

# %%
nilai_a = 4
if nilai_a < 10:
  if nilai_a % 2 == 0:
    print("Angka genap kecil")
  else:
    print("Angka ganjil kecil")
else:
  print("Angka besar")
# Out:
# Angka genap kecil

# %% [markdown]
# **Pass Statement**

# %% [markdown]
# *   Mungkin sampai saat ini timbul pertanyaan. "Bagaimana kalau suatu kondisi terpenuhi, saya tidak ingin melakukan apa-apa?"
#
# *   Jika bertemu dengan kasus seperti ini, maka yang bisa dilakukan adalah dengan menggunakan **statement pass**.
# *   Jika Python bertemu **statement pass**, maka Python tidak akan melakukan apapun dan akan **lanjut ke line berikutnya**.

# %% [markdown]
# Bono ingin membuat alarm sederhana jika genangan air di sekitar lingkungan rumahnya di atas 5 cm. Dia hanya ingin alarm berbunyi jika kondisi tersebut terjadi.
#
# Hari ini, walau situasi mulai menuju ke musim hujan genangan air di sekitar rumah Bono sebesar:

# %%
tinggi_genangan_centimeter = 4

# %% [markdown]
# Sistem peringatan Bono akan bekerja seperti ini:

# %%
tinggi_genangan_centimeter = 4

# if jika tinggi genangan kurang dari atau sama dengan 5 cm
if tinggi_genangan_centimeter <= 5:

    # pass statement bahwa jika if kondisi memenuhi maka tidak melakukan apapun
    pass

else:

    # statement jika kondisi melebihi nilai ambang maka alarm berbunyi
    print("Alarm Berbunyi!")

# %% [markdown]
# **Exercise**

# %% [markdown]
# Buatlah program untuk kondisi berikut. Jika status adalah False, program akan menampilkan "Buka semua emergency exit" Jika True, maka tidak melakukan apa-apa.

# %%
# Tuliskan jawaban anda di bawah ini

status = False

if status == True:
    pass
else:
    print("Buka semua emergency exit")
# Out:
# Buka semua emergency exit

# %% [markdown]
# Buatlah program untuk kondisi berikut. Jika angka bukan kelipatan 7, maka program akan menampilkan nilai sisa pembagian angka dengan 7. Jika kelipatan 7, maka program tidak melakukan apa-apa.

# %%
# Tuliskan jawaban anda di bawah ini

angka = 21

if angka % 7 == 0:
  pass
else:
  print(angka % 7)

# %% [markdown]
# Sebuah perkebunan menerapkan IoT (Internet of Things) dengan menggunakan sensor kelembapan sehingga dapat menyiram secara otomatis. Pemilik kebun perlu mengatur kapan untuk disiram. Jika nilai ambang kelembaban dari skala 10 kurang dari 3, maka tanaman perlu disiram. Buatlah pemrograman sensor untuk penyiraman secara otomatis di Python.

# %%
nilai_kelembaban = 4

if nilai_kelembaban < 3:
  print("Tanaman perlu disiram")
else:
  pass
