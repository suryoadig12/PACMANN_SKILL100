# %% [markdown]
# <a href="https://colab.research.google.com/github/suryoadig12/PACMANN_SKILL100/blob/main/Basic%20Python%20Programming/4.1%20Boolean%3A%20Boolean%20Logic%20I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Boolean Logic I**

# %% [markdown]
# Terdapat tiga operasi logic dasar boolean yaitu:
#
# *   AND
#
# *   OR
# *   NOT

# %% [markdown]
# **AND**

# %% [markdown]
# Secara sederhana, `and` memiliki karakteristik sebagai berikut:
#
#
#
# *   Nilai `TRUE` hanya bisa diperoleh jika dua nilai bernilai `TRUE`.
# *   Secara fisik adalah irisan antara dua kondisi.

# %% [markdown]
# ![ladsjfls.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# *   Irisan pada warna kuning merupakan nilai yang memenuhi dari kedua kondisi.

# %% [markdown]
# ![klsajfsdowe.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# **Berikut penggunaan and pada bahasa pemrograman Python.**

# %%
print(True and True)
# Out:
# True

# %%
True and False
# Out:
# False

# %%
print(3 < 4 and 3 > 1)
# Out:
# True

# %%
3 < 4 and 3 < 2
# True and False
# Out:
# False

# %% [markdown]
# **Contoh Case:**

# %% [markdown]
# Seorang Data Analyst ingin mendata pengguna aplikasi e-commerce untuk mengetahui apakah pengguna aplikasi tersebut menggunakan promo pertama dan promo kedua. Dan ternyata didapatkan beberapa kondisi yaitu:

# %%
#Pengguna menggunakan promo pertama dan promo kedua
is_get_promo_pertama = True
is_get_promo_kedua = True

is_get_promo_pertama and is_get_promo_kedua
# Out:
# True

# %%
#Pengguna menggunakan promo pertama saja
is_get_promo_pertama = True
is_get_promo_kedua = False

is_get_promo_pertama and is_get_promo_kedua
# Out:
# False

# %%
#Pengguna menggunakan promo kedua saja
is_get_promo_pertama = False
is_get_promo_kedua = True

is_get_promo_pertama and is_get_promo_kedua
# Out:
# False

# %%
#Pengguna yang tidak menggunakan promo
is_get_promo_pertama = False
is_get_promo_kedua = False

is_get_promo_pertama and is_get_promo_kedua
# Out:
# False

# %% [markdown]
# **Concept Exercise**

# %% [markdown]
# **True And True** maka outputnya adalah?
#
# Tulis jawaban di bawah ini (klik dua kali teks ini untuk menulis jawaban)
#
# Jawabannya adalah **True**

# %% [markdown]
# **True And False** maka outputnya adalah?
#
# Tulis jawaban di bawah ini (klik dua kali teks ini untuk menulis jawaban)
#
# **False**

# %% [markdown]
# **4 > 3 And 4 > 5** maka outputnya adalah?
#
# Tulis jawaban di bawah ini (klik dua kali teks ini untuk menulis jawaban)
#
# **False**

# %% [markdown]
# **Code Exercise**

# %% [markdown]
# Buatlah kondisi boolean untuk angka_1 sama dengan 10 dan angka_1 kurang dari 20.

# %%
angka_1 = 10

#Tulis Jawaban dibawah ini
angka_1 == 10 and angka_1 < 20
# Out:
# True

# %% [markdown]
# Buatlah boolean logic untuk angka_1 lebih dari sama dengan 50 dan angka_1 tidak sama dengan 17.

# %%
angka_1 = 17

#Tulis Jawaban dibawah ini
angka_1 >= 50 and angka_1 != 17
# Out:
# False

# %% [markdown]
# Perusahaan memberikan bonus insentif lebih untuk karyawan yang masuk tepat waktu dan juga setidaknya 1 kali lembur dalam sebulan. Pak Wira pernah melakukan lembur namun ia pernah terlambat maka, Buatlah boolean logic sesuai dengan kondisi Pak Wira.

# %%
# Tuliskan jawaban anda di bawah ini

tepat_waktu = False
lembur = True
tepat_waktu and lembur
# Out:
# False

# %% [markdown]
# *   Pada perusahaan A memiliki 3 karyawan - 2 karyawan Fresh Graduate, 1 karyawan senior.
#
# *   Pada tiap tanggal 28, karyawan akan mendapatkan gaji.
#
# *   2 karyawan Fresh Graduate mendapatkan gaji 15 juta rupiah, dan 1 karyawan senior mendapatkan gaji 15 juta rupiah.
# *   Dalam perusahaan tersebut karyawan Fresh Graduate mendapatkan gaji yang lebih rendah dibandingkan karyawan senior.
#
# *   Jika karyawan Fresh Graduate memiliki gaji yang sama dengan karyawan senior, maka akan naik jabatan.
#
# *   Berdasarkan pernyataan tersebut, apakah 2 karyawan Fresh Graduate naik jabatan dibulan ini?

# %%
# Tulis jawaban anda di bawah ini

FG_1 = 15_000_000
FG_2 = 15_000_000
Karyawan_senior = 15_000_000

FG_1 == Karyawan_senior and FG_2 == Karyawan_senior
# Out:
# True

# %% [markdown]
# **OR**

# %% [markdown]
# Secara sederhana, OR memiliki karakteristik sebagai berikut:

# %% [markdown]
# *   Nilai `TRUE` dapat diperoleh jika salah satu kondisi bernilai `TRUE`.
# *   Secara fisik, `OR` adalah gabungan antara dua kondisi.

# %% [markdown]
# ![sdlfjasd.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# *   Gabungan merupakan **mencakupi semua nilai maupun itu irisan atau diluar dari irisan**.

# %% [markdown]
# ![soiruaosfds.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# **Contoh Case:**

# %% [markdown]
# Seorang data analyst ingin mendata pengguna aplikasi e-commerce apakah pengguna aplikasi setidaknya menggunakan salah satu promo pertama dan promo kedua, maka dapat ditulis sebagai berikut:

# %%
#Pengguna menggunakan promo pertama atau promo kedua
is_get_promo_pertama = True
is_get_promo_kedua = True

is_get_promo_pertama or is_get_promo_kedua
# Out:
# True

# %%
#Pengguna menggunakan promo pertama saja
is_get_promo_pertama = True
is_get_promo_kedua = False

is_get_promo_pertama or is_get_promo_kedua
# Out:
# True

# %%
#Pengguna menggunakan promo kedua saja
is_get_promo_pertama = False
is_get_promo_kedua = True

is_get_promo_pertama or is_get_promo_kedua
# Out:
# True

# %%
#Pengguna yang tidak menggunakan promo
is_get_promo_pertama = False
is_get_promo_kedua = False

is_get_promo_pertama or is_get_promo_kedua
# Out:
# False

# %% [markdown]
# **Berikut penggunaan OR pada python**

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %%
3 < 4 or 3 < 2
# Out:
# True

# %%
1 > 2 or 3 < 2
# Out:
# False

# %% [markdown]
# **Concept Exercise**

# %% [markdown]
# **True Or False** maka outputnya adalah
#
# Tulis jawaban di bawah ini (klik dua kali teks ini untuk menulis jawaban)
#
# **True**

# %% [markdown]
# **10 > 17 Or 20 > 11** maka outputnya adalah
#
# Tulis jawaban di bawah ini (klik dua kali teks ini untuk menulis jawaban)
#
# **True**

# %% [markdown]
# Pengguna aplikasi e-commerce mendapatkan voucher belanja jika memenuhi salah satu ketentuan yaitu belanja **7 hari berturut-turut** atau belanja lebih dari 1 juta, Hilmi tidak belanja 7 hari berturut-turut namun ia telah melakukan transaksi 1 juta, apakah Hilmi mendapatkan voucher belanja? (True/False)
#
# Tulis jawaban di bawah ini (klik dua kali teks ini untuk menulis jawaban)
#
# **True**

# %% [markdown]
# **Code Exercise**

# %% [markdown]
# Buatlah kondisi boolean angka_1 kurang dari 5 atau angka_1 lebih dari 7.

# %%
angka_1 = 4

#Tulis jawaban dibawah ini
angka_1 < 5 or angka_1 > 7
# Out:
# True

# %% [markdown]
# Buatlah kondisi boolean angka_2 kurang dari 10 atau angka_2 lebih dari 15.

# %%
angka_2 = 12

#Tulis jawaban dibawah ini
angka_2 < 10 or angka_2 > 15
# Out:
# False

# %% [markdown]
# *   Usaha Udang milik Pak Anto ingin mengajukan kepada Investor untuk mengembangkan usahanya lebih baik.
#
# *   Investor memiliki ketentuan yaitu pendapatan Pak Anto harus mengalami kenaikan di salah satu kuartal dibandingkan pada tahun sebelumnya.
#
# *   Setelah di analisa, ternyata Pak Anto mengalami kenaikan pendapatan di salah satu kuartal. Berikut adalah hasilnya:
#
# *   Q1 = Mengalami kenaikan
# *   Q2 = Tidak mengalami kenaikan
#
#
# *   Q3 = Tidak mengalami kenaikan
#
#
# *   Q4 = Mengalami kenaikan
#
#
# *   Buatlah Logika Boolean dalam Python!

# %%
q1 = True
q2 = False
q3 = False
q4 = True
q1 or q2 or q3 or q4
# Out:
# True
